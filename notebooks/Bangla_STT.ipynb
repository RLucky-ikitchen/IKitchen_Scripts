# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##OpenAI Whisper

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-6iyi6n3g
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-6iyi6n3g
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %%
import whisper

# Load the Whisper model
model = whisper.load_model("medium")

# Path to the Bangla audio file
audio_path = "/content/drive/MyDrive/Voice Data/Copy of 20240401-000422_01782658954_2880_I_IKITC-all.mp3"

# Transcribe the audio
result = model.transcribe(audio_path, language='bn')

# Print the transcription
print("Transcription:")
print(result['text'])
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:15<00:00, 98.7MiB/s]
# Transcription:
#  바ühlमाckenislabí Mar income

# %%
# !pip install git+https://github.com/openai/whisper.git
# !pip install setuptools-rust
# Out:
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-uc2i6jdx
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-uc2i6jdx
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import whisper

# Load the Whisper model
model = whisper.load_model("base")

# Path to your audio file
audio_file = "/content/drive/MyDrive/Voice Data/Copy of 20240401-000422_01782658954_2880_I_IKITC-all.mp3"

# Transcribe the audio
result = model.transcribe(audio_file)

# Print the transcription
print(result["text"])
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:00<00:00, 198MiB/s]
#  Assalamu alaikum, la Whole Bay hacking到 WA LetterONA ... ... ...ELL .. .. .. .. ... ... .. ... .. .. ...

# %%
result = model.transcribe(audio_file, language="bn")

# %%
print(result["text"])
# Out:
#  Assalamualikum, lawal backвин t beetle supala hain Hol Hang Shams abn ez er golden aerial lake Fr프 sofortakat tb chis졌aktir money akukur ese modify votatu ve hys caldom tb chis였et no iv dhaba min ke bas umetha dut Peter por ak Hap duas Jis collectively dropped Foods Lahore

# %%
with open("transcription.txt", "w", encoding="utf-8") as f:
    f.write(result["text"])

# %%
# !pip install pydub

# %%
import whisper
from pydub import AudioSegment
from pydub.effects import normalize

# Load the largest Whisper model
model = whisper.load_model("base")

# Load and preprocess the audio file
audio = AudioSegment.from_mp3("/content/drive/MyDrive/Voice Data/Copy of 20240401-000422_01782658954_2880_I_IKITC-all.mp3")
normalized_audio = normalize(audio)
normalized_audio.export("normalized_audio.wav", format="wav")

# Path to the normalized audio file
audio_path = "normalized_audio.wav"

# Transcribe the audio with language set to Bangla
result = model.transcribe(audio_path, language='bn', task='transcribe')

# Print the transcription
print("Transcription:")
print(result['text'])
# Out:
# Transcription:
# dinbrɪz água h Butомуfi jiwani ce ndagur ڈیسے ڈیسے ڈیس ڈیسے

# %%
import whisper
import numpy as np
from pydub import AudioSegment
import os

def preprocess_audio(file_path, target_dBFS=-20):
    audio = AudioSegment.from_file(file_path, format="mp3")
    change_in_dBFS = target_dBFS - audio.dBFS
    return audio.apply_gain(change_in_dBFS)

def transcribe_audio(model, audio_file, chunk_length_ms=30000):
    audio = preprocess_audio(audio_file)
    chunks = [audio[i:i+chunk_length_ms] for i in range(0, len(audio), chunk_length_ms)]

    transcription = ""
    for chunk in chunks:
        chunk_file = "temp_chunk.wav"
        chunk.export(chunk_file, format="wav")
        result = model.transcribe(chunk_file, language="bn")
        transcription += result["text"] + " "
        os.remove(chunk_file)

    return transcription.strip()

# Load the Whisper model
model = whisper.load_model("medium")

# Path to your audio file
audio_file = "/content/drive/MyDrive/Voice Data/Copy of 20240401-000422_01782658954_2880_I_IKITC-all.mp3"

# Transcribe the audio
transcription = transcribe_audio(model, audio_file)

# Print the transcription
print(transcription)

# Save the transcription
with open("transcription.txt", "w", encoding="utf-8") as f:
    f.write(transcription)
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:16<00:00, 92.8MiB/s]
# abuslomathe hal kun Creo Fiîn tre t Ear   screams  hebt

# %% [markdown]
# ## Huggingface ASR

# %%
import os
import librosa
import torch
import torchaudio
import numpy as np

from transformers import WhisperTokenizer
from transformers import WhisperProcessor
from transformers import WhisperFeatureExtractor
from transformers import WhisperForConditionalGeneration

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

mp3_path = "/content/drive/MyDrive/Voice Data/Copy of 20240401-000422_01782658954_2880_I_IKITC-all.mp3"

model_path = "bangla-speech-processing/BanglaASR"


feature_extractor = WhisperFeatureExtractor.from_pretrained(model_path)
tokenizer = WhisperTokenizer.from_pretrained(model_path)
processor = WhisperProcessor.from_pretrained(model_path)
model = WhisperForConditionalGeneration.from_pretrained(model_path).to(device)


speech_array, sampling_rate = torchaudio.load(mp3_path, format="mp3")
speech_array = speech_array[0].numpy()
speech_array = librosa.resample(np.asarray(speech_array), orig_sr=sampling_rate, target_sr=16000)
input_features = feature_extractor(speech_array, sampling_rate=16000, return_tensors="pt").input_features

# batch = processor.feature_extractor.pad(input_features, return_tensors="pt")
predicted_ids = model.generate(inputs=input_features.to(device))[0]


transcription = processor.decode(predicted_ids, skip_special_tokens=True)

print(transcription)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Mozilla DeepSpeech

# %%
# !pip install deepspeech
# !pip install numpy scipy
# Out:
# ERROR: Could not find a version that satisfies the requirement deepspeech (from versions: none)
# ERROR: No matching distribution found for deepspeech
# ...

# %%
# !pip3 install deepspeech-gpu
# Out:
# ERROR: Could not find a version that satisfies the requirement deepspeech-gpu (from versions: none)
# ERROR: No matching distribution found for deepspeech-gpu

# %%
import deepspeech
import numpy as np
import wave

# Function to load audio file
def load_audio(audio_path):
    with wave.open(audio_path, 'rb') as w:
        rate = w.getframerate()
        frames = w.getnframes()
        buffer = w.readframes(frames)
    return buffer, rate

# Path to DeepSpeech model files
model_path = 'path/to/deepspeech-0.9.3-models.pbmm'
scorer_path = 'path/to/deepspeech-0.9.3-models.scorer'

# Load DeepSpeech model
model = deepspeech.Model(model_path)
model.enableExternalScorer(scorer_path)

# Path to your audio file
audio_file = '/content/drive/MyDrive/Voice Data/Copy of 20240401-000422_01782658954_2880_I_IKITC-all.mp3'

# Load audio file
audio, sample_rate = load_audio(audio_file)

# Convert audio to numpy array
audio = np.frombuffer(audio, np.int16)

# Perform speech recognition
text = model.stt(audio)

print(f"Transcription: {text}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-fe283ceafbf0> in <cell line: 1>()
# ----> 1 import deepspeech
#       2 import numpy as np
#       3 import wave
#       4
#       5 # Function to load audio file
#
# ModuleNotFoundError: No module named 'deepspeech'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## CMU Sphinx

# %%
# !pip install pocketsphinx
# !pip install SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.2/29.2 MB 61.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 26.8 MB/s eta 0:00:00
# ...

# %%
import os
import speech_recognition as sr
from pocketsphinx import Pocketsphinx, AudioFile

# Path to your audio file
audio_file = "/content/drive/MyDrive/Voice Data/Copy of 20240401-000422_01782658954_2880_I_IKITC-all.mp3"

# Path to the directory containing the Bengali acoustic model
acoustic_model_path = "path_to_your_bengali_acoustic_model"

# Path to the Bengali language model and dictionary
language_model_path = "path_to_your_language_model_directory/bengali.lm"
dictionary_path = "path_to_your_language_model_directory/bengali.dic"

# Set up PocketSphinx configuration
config = {
    'hmm': acoustic_model_path,        # Path to the acoustic model
    'lm': language_model_path,         # Path to the language model
    'dict': dictionary_path            # Path to the pronunciation dictionary
}

# Initialize PocketSphinx with the given configuration
ps = Pocketsphinx(**config)

# Load the audio file
ps.decode(audio_file=audio_file)

# Print the transcription
print("Transcription:")
print(ps.hypothesis())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-1ed9f9912771> in <cell line: 23>()
#      21
#      22 # Initialize PocketSphinx with the given configuration
# ---> 23 ps = Pocketsphinx(**config)
#      24
#      25 # Load the audio file
#
# /usr/local/lib/python3.10/dist-packages/pocketsphinx/__init__.py in __init__(self, **kwargs)
#     107             kwargs["loglevel"] = "INFO"
#     108         self.start_frame = 0
# --> 109         super(Pocketsphinx, self).__init__(**kwargs)
#     110
#     111     def __str__(self):
#
# _pocketsphinx.pyx in _pocketsphinx.Decoder.__init__()
#
# RuntimeError: Failed to initialize PocketSphinx

# %%
import os
import speech_recognition as sr
from pocketsphinx import Pocketsphinx, AudioFile

# Path to your audio file
audio_file = "/content/normalized_audio.wav"

# **VERIFY THESE PATHS** - Path to the directory containing the Bengali acoustic model
acoustic_model_path = "path_to_your_bengali_acoustic_model"

# **VERIFY THESE PATHS** - Path to the Bengali language model and dictionary
language_model_path = "path_to_your_language_model_directory/bengali.lm"
dictionary_path = "path_to_your_language_model_directory/bengali.dic"

# Set up PocketSphinx configuration
config = {
    'hmm': acoustic_model_path,        # Path to the acoustic model
    'lm': language_model_path,         # Path to the language model
    'dict': dictionary_path,           # Path to the pronunciation dictionary
    'loglevel': 'DEBUG'                # Set log level to debug for more verbose output
}

# Initialize PocketSphinx with the given configuration
try:
    ps = Pocketsphinx(**config)
except RuntimeError as e:
    print(f"Error initializing Pocketsphinx: {e}")
    # Print more details about the configuration to help diagnose the issue
    print("Configuration used:")
    for key, value in config.items():
        print(f"{key}: {value}")

# Initialize PocketSphinx with the given configuration
ps = Pocketsphinx(**config)

# Load the audio file
ps.decode(audio_file=audio_file)

# Print the transcription
print("Transcription:")
print(ps.hypothesis())
# Out:
# Error initializing Pocketsphinx: Failed to initialize PocketSphinx
# Configuration used:
# hmm: path_to_your_bengali_acoustic_model
# lm: path_to_your_language_model_directory/bengali.lm
# dict: path_to_your_language_model_directory/bengali.dic
# loglevel: DEBUG
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-3ac81ce4b61a> in <cell line: 34>()
#      32
#      33 # Initialize PocketSphinx with the given configuration
# ---> 34 ps = Pocketsphinx(**config)
#      35
#      36 # Load the audio file
#
# /usr/local/lib/python3.10/dist-packages/pocketsphinx/__init__.py in __init__(self, **kwargs)
#     107             kwargs["loglevel"] = "INFO"
#     108         self.start_frame = 0
# --> 109         super(Pocketsphinx, self).__init__(**kwargs)
#     110
#     111     def __str__(self):
#
# _pocketsphinx.pyx in _pocketsphinx.Decoder.__init__()
#
# ...

# %%
import speech_recognition as sr

recognizer = sr.Recognizer()
with sr.AudioFile('/content/normalized_audio.wav') as source:
    audio = recognizer.record(source)
    try:
        text = recognizer.recognize_sphinx(audio)
        print("Transcription:", text)
    except sr.UnknownValueError:
        print("Sphinx could not understand the audio")
    except sr.RequestError as e:
        print(f"Sphinx error: {e}")
# Out:
# Transcription: the the long ride with you and you're looking a loophole in the heat on the eve in as he says he pulled the killer in the validity of palm of them live in relation to come on down the one that prayer you did and will will you be a good up to our

# %%
from pocketsphinx import Pocketsphinx

ps = Pocketsphinx()
ps.decode(audio_file='/content/normalized_audio.wav')
print("Transcription:", ps.hypothesis())
# Out:
# Transcription: that that for op op op op op little effect on top op of what will you had the who what and the alternative all although who would look up and pack

# %% [markdown]
# ## Medium Bangla STT

# %%
# !pip install banglaspeech2text
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
from banglaspeech2text import Speech2Text

stt = Speech2Text(model="base")

# You can use it wihout specifying model name (default model is "base")
stt = Speech2Text()
# Out:
# config.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/290M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/827 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.06k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# ...

# %%
transcription = stt.transcribe("/content/normalized_audio.wav")
print(transcription)
# Out:
# /usr/local/lib/python3.10/dist-packages/banglaspeech2text/speech2text.py:350: UserWarning: transcribe is deprecated. Use recognize instead
#   warnings.warn("transcribe is deprecated. Use recognize instead")
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:480: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-2e0a11e0d57c> in <cell line: 1>()
# ----> 1 transcription = stt.transcribe("/content/normalized_audio.wav")
#       2 print(transcription)
#
# /usr/local/lib/python3.10/dist-packages/banglaspeech2text/speech2text.py in transcribe(self, audio_path, *args, **kw)
#     349         """
#     350         warnings.warn("transcribe is deprecated. Use recognize instead")
# ...

# %%
# !pip install --upgrade transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 61.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.42.4
#     Uninstalling transformers-4.42.4:
#       Successfully uninstalled transformers-4.42.4
# ...

# %%
from banglaspeech2text import Speech2Text
from transformers import WhisperConfig, WhisperTokenizer, WhisperForConditionalGeneration

# Load the pre-trained Whisper model and tokenizer
model_name = "openai/whisper-base"
config = WhisperConfig.from_pretrained(model_name)
tokenizer = WhisperTokenizer.from_pretrained(model_name)
model = WhisperForConditionalGeneration.from_pretrained(model_name)

# Enable timestamp generation in the configuration
config.return_timestamps = True
# Access the 'no_timestamps_token' through the tokenizer
config.no_timestamps_token = tokenizer.no_speech_token # Use no_speech_token instead of no_timestamps_token

# Initialize Speech2Text with the updated configuration
stt = Speech2Text(model=model, config=config, tokenizer=tokenizer)

# Transcribe the audio file
transcription = stt.transcribe("/content/normalized_audio.wav")
print(transcription)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.98k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# ...

# %%
from banglaspeech2text import Speech2Text
from transformers import WhisperConfig, WhisperTokenizer, WhisperForConditionalGeneration

# Load the pre-trained Whisper model and tokenizer
model_name = "openai/whisper-base"
config = WhisperConfig.from_pretrained(model_name)
tokenizer = WhisperTokenizer.from_pretrained(model_name)
model = WhisperForConditionalGeneration.from_pretrained(model_name)

# Enable timestamp generation in the configuration
config.return_timestamps = True
# Access the 'no_timestamps_token' through the tokenizer
config.no_timestamps_token = tokenizer.pad_token # Use pad_token instead of no_speech_token

# Initialize Speech2Text with the model name as a string
stt = Speech2Text(model=model_name, config=config, tokenizer=tokenizer) # Pass model_name instead of model object

# Transcribe the audio file
transcription = stt.transcribe("/content/drive/MyDrive/Voice Data/Copy of 20240401-000422_01782658954_2880_I_IKITC-all.mp3")
print(transcription)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/banglaspeech2text/speech2text.py:350: UserWarning: transcribe is deprecated. Use recognize instead
#   warnings.warn("transcribe is deprecated. Use recognize instead")
# /usr/local/lib/python3.10/dist-packages/transformers/models/whisper/generation_whisper.py:480: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
#  । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । । Thank you. Hello, hello.

# %% [markdown]
# ## wav2vec 2.0

# %%
# !pip install torch transformers datasets soundfile
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# ...

# %%
# !pip install torch transformers librosa
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# ...

# %%
import torch
import librosa
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

# Load pre-trained model and processor
model_name = "arijitx/wav2vec2-xls-r-300m-bengali"
processor = Wav2Vec2Processor.from_pretrained(model_name)
model = Wav2Vec2ForCTC.from_pretrained(model_name)

# Load audio file
audio_file = "/content/normalized_audio.wav"
speech, sample_rate = librosa.load(audio_file, sr=16000)

# Tokenize
input_values = processor(speech, sampling_rate=16000, return_tensors="pt").input_values

# Retrieve logits
with torch.no_grad():
    logits = model(input_values).logits

# Decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)[0]

print(transcription)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Some weights of the model checkpoint at arijitx/wav2vec2-xls-r-300m-bengali were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
import torch
import librosa
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

# Load pre-trained model and processor
model_name = "sshasnain/wav2vec2-xls-r-300m-bangla-command-synthetic"
processor = Wav2Vec2Processor.from_pretrained(model_name)
model = Wav2Vec2ForCTC.from_pretrained(model_name)

# Load audio file
audio_file = "/content/normalized_audio.wav"
speech, sample_rate = librosa.load(audio_file, sr=16000)

# Tokenize
input_values = processor(speech, sampling_rate=16000, return_tensors="pt").input_values

# Retrieve logits
with torch.no_grad():
    logits = model(input_values).logits

# Decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)[0]

print(transcription)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/355 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# ...

# %%
import torch
import librosa
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor

# Load pre-trained model and processor
model_name = "auditi41/wav2vec2-large-xlsr-53-Bangla"
processor = Wav2Vec2Processor.from_pretrained(model_name)
model = Wav2Vec2ForCTC.from_pretrained(model_name)

# Load audio file
audio_file = "/content/normalized_audio.wav"
speech, sample_rate = librosa.load(audio_file, sr=16000)

# Tokenize
input_values = processor(speech, sampling_rate=16000, return_tensors="pt").input_values

# Retrieve logits
with torch.no_grad():
    logits = model(input_values).logits

# Decode
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)[0]

print(transcription)
# Out:
# preprocessor_config.json:   0%|          | 0.00/214 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.02k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.31k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Some weights of the model checkpoint at auditi41/wav2vec2-large-xlsr-53-Bangla were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...
